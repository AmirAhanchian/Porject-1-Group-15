# %%
import pandas as pd

# %%
country_data_df = pd.read_csv("../output_data/countries.csv", index_col="Country_ID")

country_data_df
# Out:
#                         Country Geographical Coordinates  \
# Country_ID
# 0                       Algeria          28 00 N, 3 00 E
# 1                        Angola         12 30 S, 18 30 E
# 2                      Botswana         22 00 S, 24 00 E
# 3                     Australia        27 00 S, 133 00 E
# 4                   New Zealand        41 00 S, 174 00 E
# 5           Antigua and Barbuda         17 03 N, 61 48 W
# 6                      Barbados         13 10 N, 59 32 W
# 7                       Albania         41 00 N, 20 00 E
# 8                       Austria         47 20 N, 13 20 E
# 9                       Germany          51 00 N, 9 00 E
# 10               United Kingdom          54 00 N, 2 00 W
# 11                       Canada         60 00 N, 95 00 W
# 12                       Mexico        23 00 N, 102 00 W
# 13                United States         38 00 N, 97 00 W
#
#                       GDP (Adjusted to $US)  \
# Country_ID
# ...
