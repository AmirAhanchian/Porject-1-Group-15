# %%
# %matplotlib notebook

# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import our data into pandas from CSV
country_data = '../output_data/Cleaned_Countries_Data.csv'
data_df = pd.read_csv(country_data, low_memory=False)

data_df.head()
# Out:
#    Unnamed: 0   Country   Lat   Long  GDP (billion USD)  \
# 0           0   Algeria  28.0   3.00             169.91
# 1           1    Angola -12.3  18.30              97.26
# 2           2  Botswana -22.0  24.00              18.34
# 3           3     Benin   9.3   2.15              10.31
# 4           4   Burundi  -3.3  30.00               3.03
#
#    Real GDP 2020 (billion USD)  Real GDP Per Capita 2020  \
# 0                       468.40                   10700.0
# 1                       203.71                    6200.0
# 2                        37.72                   16000.0
# 3                        40.29                    3300.0
# 4                         8.69                     700.0
#
#    Wasted Generated Annually (million tons)  \
# 0                                     12.38
# 1                                      4.21
# 2                                      0.21
# 3                                      0.69
# 4                                      1.87
#
#   Wasted Recycled Annually (million tons) % of Wasted Recycled Annually  \
# 0                                    0.99                             8
# 1                                 No Data                       No Data
# 2                                     0.0                             1
# 3                                    0.17                            25
# 4                                 No Data                       No Data
#
#    Particulate Matter Emissions (micrograms per m3)  C02 Emissions (megatons)  \
# 0                                             35.17                    150.01
# 1                                             27.95                     34.69
# 2                                             21.24                      6.34
# 3                                             33.11                      6.48
# 4                                             35.61                      0.50
#
#    Methane  Emissions (megatons)  Electricity by Unclean Energy (%)  \
# 0                          49.94                               98.9
# 1                          23.28                               28.4
# 2                           5.73                               99.8
# 3                           5.80                               96.9
# 4                           1.42                               33.3
#
#    Electricity by Clean Energy (%)  Urban Population (%)  Net Migration  \
# 0                              1.1                  74.8          -0.82
# 1                             71.6                  68.1          -0.19
# 2                              0.2                  72.2           2.81
# 3                              3.1                  49.5           0.24
# 4                             66.7                  14.4           7.09
#
#    Total Agreement
# 0            -0.82
# 1            -0.19
# 2             2.81
# 3             0.24
# 4             7.09

# %%
# Filter total recycling and recycling % data so it only includes valid outputs
recycling_data_df = pd.DataFrame(data_df.loc[data_df['Wasted Recycled Annually (million tons)']>0,:])
recycling_data_df = pd.DataFrame(data_df.loc[data_df['% of Wasted Recycled Annually']>0,:])

# data_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 # Filter total recycling and recycling % data so it only includes valid outputs
# ----> 2 recycling_data_df = pd.DataFrame(data_df.loc[data_df['Wasted Recycled Annually (million tons)']>0,:])
#       3 recycling_data_df = pd.DataFrame(data_df.loc[data_df['% of Wasted Recycled Annually']>0,:])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# -> 5623     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5625 return self._construct_result(res_values, name=res_name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:283, in comparison_op(left, right, op)
#     280     return invalid_comparison(lvalues, rvalues, op)
#     282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#     286     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73, in comp_method_OBJECT_ARRAY(op, x, y)
#      71     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72 else:
# ---> 73     result = libops.scalar_compare(x.ravel(), y, op)
#      74 return result.reshape(x.shape)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# recycling_data_df.head()
